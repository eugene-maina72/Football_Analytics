# %% [markdown]
# ##Football Pitch Layout

# %%
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch

# %%
#Ploting a paitch on a new axis
pitch=Pitch()
#Specify the size of the pitch
fig, ax = pitch.draw(figsize=(8, 4))

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)
pitch =Pitch()
pie = axs[0].pie(x=[5, 15])
pitch.draw(ax=axs[1])

# %%
#Drawing pitch templates they include (Opta ,Wyscout,StatsBomb,Tracab,Uefa,metricasports,custom,skillcorner,secondspectrum and impect)
#For (‘metricasports’, ‘tracab’, ‘skillcorner’, ‘secondspectrum’ or ‘custom’) you also need to specify the pitch_length and pitch_width, which are typically 105 and 68 respectively.
pitch =Pitch(pitch_type='opta')
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_type='skillcorner',
              pitch_length=105, pitch_width=68
              , axis=True, label=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch()
fig, axs = pitch.draw(nrows=2, ncols=3)

# %%
pitch = Pitch()
fig, axs = pitch.draw(nrows=2, ncols=3, tight_layout=True, constrained_layout=True)

# %%
pitch = Pitch()
fig, axs = pitch.grid(nrows=2, ncols=3, figheight=10,
                      #Grid takes up 71.5% of the figure height
                      grid_height=0.715,
                      #5% of the figure height is reserved for space inbetween the axes
                      space=0.05,
                      #Centres the grid horizontally and vertically
                      left=None, bottom=None
                      )

# %%
pitch = Pitch(half= False)
fig, ax = pitch.draw()

# %%
pitch = VerticalPitch(half=True)
fig, ax = pitch.draw()

# %%
pitch = VerticalPitch(half=True,
                      pad_left=-10,  # bring the left axis in 10 data units (reduce the size)
                      pad_right=-10,  # bring the right axis in 10 data units (reduce the size)
                      pad_top=10,  # extend the top axis 10 data units
                      pad_bottom=20)  # extend the bottom axis 20 data units
fig, ax = pitch.draw()

# %%
pitch=Pitch(pitch_color='#aabb97', line_color='white', stripe_color='#c2d59d', stripe=True, linestyle='--', linewidth=1, goal_linestyle='-', corner_arcs=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch(line_alpha=0.5, goal_alpha=0.3)
fig, ax = pitch.draw()

# %% [markdown]
# ### CORNER ARCS

# %%
pitch = VerticalPitch(corner_arcs=True, half=True, pitch_color='grass')
fig, ax = pitch.draw(figsize=(10, 7.727))

# %% [markdown]
# ### POSITIONAL PLAY LINES

# %%
pitch = Pitch(positional=True, shade_middle=True, positional_color='#eadddd', shade_color='#f2f2f2')
fig, ax = pitch.draw()

# %%
#Re-writing this as a function to call it whenever we want to plot a positional play pitch
def PepGuardiola():
    pitch = Pitch(positional=True, shade_middle=True, positional_color='#eadddd', shade_color='#f2f2f2')
    fig, ax = pitch.draw()
    print

PepGuardiola()

# %% [markdown]
# ### GOAL TYPES

# %%
fig, axs = plt.subplots(nrows=3, figsize=(10, 18))
pitch = Pitch(goal_type='box', goal_alpha=1)
pitch.draw(ax=axs[0])
pitch = Pitch(goal_type='line',)
pitch.draw(ax=axs[1])
pitch = Pitch(goal_type='circle', linewidth=1)
pitch.draw(ax=axs[2])

# %% [markdown]
# ### ADJUSTING SPOTSIZE AND LINEWIDTH

# %%
pitch = Pitch(linewidth=3,
              #Size of the penalty and spots relative to the pitch
              spot_scale=0.02)
fig, ax = pitch.draw()

# %% [markdown]
# ### LIFTING PITCHLINES ABOVE OTHER ELEMENTS

# %%
pitch = Pitch(line_zorder=2, axis=True, label=True, tick=True)
fig, ax = pitch.draw()

# %% [markdown]
# ### XKCD THEME

# %%
plt.xkcd()
pitch= Pitch(pitch_color='grass', stripe=True)
fig, ax = pitch.draw(figsize=(8, 4))
annotation= ax.annotate('This is a xkcd style pitch', (40, 10), fontsize=20, ha='center')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...
